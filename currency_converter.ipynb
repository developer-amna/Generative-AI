# %% [markdown]
# <a href="https://colab.research.google.com/github/developer-amna/Generative-AI/blob/main/currency_converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
rates = {
    "USD": 1.0,
    "PKR": 280.0,
    "EUR": 0.92,
    "GBP": 0.78,
    "INR": 83.0
}

def convert_currency(amount, from_currency, to_currency):
    if from_currency not in rates or to_currency not in rates:
        return "Invalid currency code!"

    # Convert to USD first, then to target currency
    usd_amount = amount / rates[from_currency]
    converted = usd_amount * rates[to_currency]

    return converted


while True:
    print("\n--- Currency Converter ---")
    print("Available currencies:", list(rates.keys()))
    print("Type 'exit' to quit")

    from_currency = input("From Currency: ").upper()

    if from_currency == "EXIT":
        print("Converter Closed ✅")
        break

    to_currency = input("To Currency: ").upper()
    amount = float(input("Enter Amount: "))

    result = convert_currency(amount, from_currency, to_currency)

    print("Converted Amount:", result)
# Out:
# --- Currency Converter ---
# Available currencies: ['USD', 'PKR', 'EUR', 'GBP', 'INR']
# Type 'exit' to quit
# From Currency: usd
# To Currency: pkr
# Enter Amount: 2000
# Converted Amount: 560000.0
#
# --- Currency Converter ---
# Available currencies: ['USD', 'PKR', 'EUR', 'GBP', 'INR']
# Type 'exit' to quit
# From Currency: exit
# Converter Closed ✅
